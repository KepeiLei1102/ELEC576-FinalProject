# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.io import wavfile
from scipy import fftpack
from scipy.signal import decimate

root = 'C:/Users/Joseph/Downloads/'
trainpath = root + 'TrainRaw/'
# testpath = root + 'TestRaw/'

# %%
# def create_matrix(path, train = True):
filenames = sorted([f for f in os.listdir(trainpath) if f[-3:]=='wav' and f[-5]=='b'])
print(len(filenames))
dec_factor = 2
X = np.zeros((len(filenames),int(441000/dec_factor)))
y = np.zeros((len(filenames),1)) - 1
label_dict = {'airport': 0, 'bus': 1, 'metro': 2}
lengths = []

for i, f in enumerate(filenames):
    samplerate, data = wavfile.read(trainpath+f)
#     print(data.shape)
    data = decimate(data, dec_factor)
    lengths.append(len(data))

    X[i,:len(data)] = data
    label = f.split('-')[0]
    y[i] = label_dict[label]
#     if i%20 == 0:
    print(f)

# np.save(root+'train_data_matrix_ds=2', X)
# np.save(root+'train_labels', y)

# create_matrix(trainpath, True)
# create_matrix(testpath, False)
# Out:
# 284
# airport-barcelona-1-41-b.wav
# airport-barcelona-1-47-b.wav
# airport-barcelona-1-61-b.wav
# airport-barcelona-1-67-b.wav
# airport-barcelona-1-71-b.wav
# airport-barcelona-1-72-b.wav
# airport-barcelona-1-91-b.wav
# airport-barcelona-2-109-b.wav
# airport-barcelona-203-6122-b.wav
# airport-barcelona-203-6130-b.wav
# airport-barcelona-203-6131-b.wav
# airport-helsinki-204-6141-b.wav
# airport-helsinki-204-6148-b.wav
# airport-helsinki-204-6159-b.wav
# airport-helsinki-204-6160-b.wav
# airport-helsinki-3-147-b.wav
# airport-helsinki-3-164-b.wav
# airport-helsinki-3-167-b.wav
# airport-helsinki-3-168-b.wav
# airport-helsinki-4-183-b.wav
# airport-helsinki-4-196-b.wav
# airport-helsinki-4-219-b.wav
# airport-helsinki-4-220-b.wav
# airport-lisbon-1000-41194-b.wav
# airport-lisbon-1114-42669-b.wav
# airport-lisbon-1114-42954-b.wav
# airport-lisbon-1114-43793-b.wav
# airport-lisbon-1122-40344-b.wav
# airport-lisbon-1122-41394-b.wav
# airport-lisbon-1122-42768-b.wav
# airport-lisbon-1122-43567-b.wav
# airport-lisbon-1175-44669-b.wav
# airport-lisbon-1175-44916-b.wav
# airport-lisbon-1175-45213-b.wav
# airport-lisbon-1175-45350-b.wav
# airport-london-205-6190-b.wav
# airport-london-205-6202-b.wav
# airport-london-205-6203-b.wav
# airport-london-5-230-b.wav
# airport-london-5-242-b.wav
# airport-london-5-246-b.wav
# airport-london-6-258-b.wav
# airport-london-6-271-b.wav
# airport-london-6-295-b.wav
# airport-london-6-300-b.wav
# airport-london-6-302-b.wav
# airport-lyon-1041-41166-b.wav
# airport-lyon-1041-41176-b.wav
# airport-lyon-1041-41824-b.wav
# airport-lyon-1041-41843-b.wav
# airport-lyon-1041-43878-b.wav
# airport-lyon-1101-41912-b.wav
# airport-lyon-1101-43537-b.wav
# airport-lyon-1101-44017-b.wav
# airport-lyon-1169-44127-b.wav
# airport-lyon-1169-45129-b.wav
# airport-lyon-1169-45263-b.wav
# metro-barcelona-42-1296-b.wav
# metro-helsinki-221-6682-b.wav
# metro-helsinki-221-6683-b.wav
# metro-helsinki-222-6709-b.wav
# metro-helsinki-222-6720-b.wav
# metro-helsinki-45-1333-b.wav
# metro-helsinki-45-1338-b.wav
# metro-helsinki-45-1345-b.wav
# metro-helsinki-45-1355-b.wav
# metro-helsinki-45-1358-b.wav
# metro-helsinki-45-1359-b.wav
# metro-helsinki-45-1361-b.wav
# metro-helsinki-45-1363-b.wav
# metro-lisbon-1055-40480-b.wav
# metro-lisbon-1055-42714-b.wav
# metro-lisbon-1119-40333-b.wav
# metro-lisbon-1119-42785-b.wav
# metro-lisbon-1121-42509-b.wav
# metro-lisbon-1121-42653-b.wav
# metro-lisbon-1121-43334-b.wav
# metro-lisbon-1160-40925-b.wav
# metro-lisbon-1199-45418-b.wav
# metro-lisbon-1199-45513-b.wav
# metro-lisbon-1199-45637-b.wav
# metro-lisbon-1224-45653-b.wav
# metro-london-223-6773-b.wav
# metro-london-223-6774-b.wav
# metro-london-223-6777-b.wav
# metro-london-46-1377-b.wav
# metro-london-46-1389-b.wav
# metro-london-46-1393-b.wav
# metro-london-46-1417-b.wav
# metro-london-47-1441-b.wav
# metro-london-48-1446-b.wav
# metro-london-48-1453-b.wav
# metro-london-48-1488-b.wav
# metro-lyon-1064-40950-b.wav
# metro-lyon-1064-41478-b.wav
# metro-lyon-1079-40441-b.wav
# metro-lyon-1126-40874-b.wav
# metro-lyon-1126-42110-b.wav
# metro-lyon-1126-43599-b.wav
# metro-lyon-1149-41054-b.wav
# metro-lyon-1149-42306-b.wav
# metro-lyon-1181-44494-b.wav
# metro-lyon-1201-44196-b.wav
# metro-lyon-1201-45136-b.wav
# metro-milan-1025-40143-b.wav
# metro-milan-1141-40385-b.wav
# metro-milan-1141-42061-b.wav
# metro-milan-1142-42353-b.wav
# metro-milan-1142-42787-b.wav
# metro-milan-1142-44028-b.wav
# metro-milan-1143-43882-b.wav
# metro-milan-1218-44438-b.wav
# metro-milan-1218-44544-b.wav
# metro-milan-1218-45486-b.wav
# metro-paris-225-6796-b.wav

# %%
np.save(root+'train_data_matrix_mono_ds=2', X)
np.save(root+'train_labels_mono', y)

# %%
# X_train_ds2 = np.load(root+'train_data_matrix_ds=2.npy')
# np.save(root+'train_data_matrix_2e5samples', X_train[:, :200000])
# X_train_ds2_fragmented = np.copy(X_train_ds2[:,:300000].reshape((2100,100000)))
# np.save(root+'train_data_matrix_2e5samples_3obsPerWav_ds=2', X_train_ds2_fragmented)
# %reset_selective X_train

# X_test_ds2 = np.load(root+'test_data_matrix_ds=2.npy')
# np.save(root+'test_data_matrix_2e5samples', X_test[:, :200000])
# X_test_ds2_fragmented = X_test_ds2[:,:300000].reshape((900,100000))
# np.save(root+'test_data_matrix_2e5samples_3obsPerWav_ds=2', X_test_ds2_fragmented)

# y_train = np.load(root+'train_labels.npy')
# np.save(root+'train_labels_3obsPerWav', np.repeat(y_train, 3))
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
